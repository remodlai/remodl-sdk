# %%
# %pip install dspy pydantic typing-extensions typing
# Out:
# Requirement already satisfied: dspy in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (3.0.4b2)
# Requirement already satisfied: pydantic in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (2.12.3)
# Requirement already satisfied: typing-extensions in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (4.15.0)
# Requirement already satisfied: typing in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (3.10.0.0)
# Requirement already satisfied: backoff>=2.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (2.2.1)
# Requirement already satisfied: joblib~=1.3 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (1.5.2)
# Requirement already satisfied: openai>=0.28.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (1.109.1)
# Requirement already satisfied: regex>=2023.10.3 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (2024.11.6)
# Requirement already satisfied: orjson>=3.9.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (3.10.15)
# Requirement already satisfied: tqdm>=4.66.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (4.67.1)
# Requirement already satisfied: requests>=2.31.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (2.31.0)
# Requirement already satisfied: optuna>=3.4.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (4.5.0)
# Requirement already satisfied: magicattr>=0.1.6 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (0.1.6)
# Requirement already satisfied: litellm>=1.64.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (1.79.1)
# Requirement already satisfied: diskcache>=5.6.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (5.6.3)
# Requirement already satisfied: json-repair>=0.30.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (0.52.3)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (9.1.2)
# Requirement already satisfied: anyio in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (4.5.2)
# Requirement already satisfied: asyncer==0.0.8 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (0.0.8)
# Requirement already satisfied: cachetools>=5.5.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (6.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (3.1.1)
# Requirement already satisfied: rich>=13.7.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (14.2.0)
# Requirement already satisfied: pillow>=10.1.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (11.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (2.3.4)
# Requirement already satisfied: xxhash>=3.5.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from dspy) (3.6.0)
# Requirement already satisfied: gepa==0.0.18 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from gepa[dspy]==0.0.18->dspy) (0.0.18)
# Requirement already satisfied: idna>=2.8 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from anyio->dspy) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from anyio->dspy) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: aiohttp>=3.10 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (3.10.11)
# Requirement already satisfied: click in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (8.1.8)
# Requirement already satisfied: fastuuid>=0.13.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (0.14.0)
# Requirement already satisfied: httpx>=0.23.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (6.11.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (4.23.0)
# Requirement already satisfied: python-dotenv>=0.2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (0.7.0)
# Requirement already satisfied: tokenizers in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.64.0->dspy) (0.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.64.0->dspy) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.64.0->dspy) (0.20.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.64.0->dspy) (1.15.2)
# Requirement already satisfied: propcache>=0.2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.12.0->aiohttp>=3.10->litellm>=1.64.0->dspy) (0.2.0)
# Requirement already satisfied: certifi in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from httpx>=0.23.0->litellm>=1.64.0->dspy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.23.0->litellm>=1.64.0->dspy) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm>=1.64.0->dspy) (3.20.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from openai>=0.28.1->dspy) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from openai>=0.28.1->dspy) (0.9.1)
# Requirement already satisfied: alembic>=1.5.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from optuna>=3.4.0->dspy) (1.17.0)
# Requirement already satisfied: colorlog in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from optuna>=3.4.0->dspy) (6.10.1)
# Requirement already satisfied: packaging>=20.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from optuna>=3.4.0->dspy) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from optuna>=3.4.0->dspy) (2.0.44)
# Requirement already satisfied: PyYAML in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from optuna>=3.4.0->dspy) (6.0.3)
# Requirement already satisfied: Mako in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from alembic>=1.5.0->optuna>=3.4.0->dspy) (1.3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from requests>=2.31.0->dspy) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from requests>=2.31.0->dspy) (2.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from rich>=13.7.1->dspy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from rich>=13.7.1->dspy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->dspy) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from tokenizers->litellm>=1.64.0->dspy) (0.36.0)
# Requirement already satisfied: filelock in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.64.0->dspy) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U mcp2py fastmcp
# Out:
# Requirement already satisfied: mcp2py in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (0.6.0)
# Requirement already satisfied: fastmcp in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (2.13.0.2)
# Requirement already satisfied: litellm>=1.0.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp2py) (1.79.1)
# Requirement already satisfied: mcp>=1.18.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp2py) (1.20.0)
# Requirement already satisfied: authlib>=1.5.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (1.6.5)
# Requirement already satisfied: cyclopts>=3.0.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (4.2.1)
# Requirement already satisfied: exceptiongroup>=1.2.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (1.3.0)
# Requirement already satisfied: httpx>=0.28.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (0.28.1)
# Requirement already satisfied: jsonschema-path>=0.3.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (0.3.4)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (0.5.1)
# Requirement already satisfied: platformdirs>=4.0.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (4.3.6)
# Requirement already satisfied: py-key-value-aio<0.3.0,>=0.2.8 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (0.2.8)
# Requirement already satisfied: pydantic>=2.11.7 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.12.3)
# Requirement already satisfied: pyperclip>=1.9.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (1.11.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (1.2.1)
# Requirement already satisfied: rich>=13.9.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (14.2.0)
# Requirement already satisfied: websockets>=15.0.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from fastmcp) (15.0.1)
# Requirement already satisfied: anyio>=4.5 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (4.5.2)
# Requirement already satisfied: httpx-sse>=0.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (2.11.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.18.0->mcp2py) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (0.0.18)
# Requirement already satisfied: sse-starlette>=1.6.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (2.1.3)
# Requirement already satisfied: starlette>=0.27 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (0.44.0)
# Requirement already satisfied: uvicorn>=0.31.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from mcp>=1.18.0->mcp2py) (0.38.0)
# Requirement already satisfied: beartype>=0.22.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-aio<0.3.0,>=0.2.8->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (0.22.5)
# Requirement already satisfied: py-key-value-shared==0.2.8 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-aio<0.3.0,>=0.2.8->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (0.2.8)
# Requirement already satisfied: typing-extensions>=4.15.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-shared==0.2.8->py-key-value-aio<0.3.0,>=0.2.8->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (4.15.0)
# Requirement already satisfied: diskcache>=5.6.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (3.3.1)
# Requirement already satisfied: keyring>=25.6.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (25.6.0)
# Requirement already satisfied: cachetools>=6.0.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (6.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic>=2.11.7->pydantic[email]>=2.11.7->fastmcp) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.18.0->mcp2py) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from anyio>=4.5->mcp>=1.18.0->mcp2py) (1.3.1)
# Requirement already satisfied: cryptography in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from authlib>=1.5.2->fastmcp) (43.0.3)
# Requirement already satisfied: attrs>=23.1.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp) (25.3.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from cyclopts>=3.0.0->fastmcp) (1.3.2)
# Requirement already satisfied: docutils in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=3.0.0->fastmcp) (0.22.2)
# Requirement already satisfied: certifi in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from httpx>=0.28.1->fastmcp) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from httpx>=0.28.1->fastmcp) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.18.0->mcp2py) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.18.0->mcp2py) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.18.0->mcp2py) (0.20.1)
# Requirement already satisfied: PyYAML>=5.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema-path>=0.3.4->fastmcp) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema-path>=0.3.4->fastmcp) (0.4.4)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jsonschema-path>=0.3.4->fastmcp) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp) (2.2.3)
# Requirement already satisfied: jaraco.classes in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (3.4.0)
# Requirement already satisfied: jaraco.functools in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (4.3.0)
# Requirement already satisfied: jaraco.context in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (6.0.1)
# Requirement already satisfied: aiohttp>=3.10 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (3.10.11)
# Requirement already satisfied: click in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (8.1.8)
# Requirement already satisfied: fastuuid>=0.13.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (0.14.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (6.11.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (3.1.6)
# Requirement already satisfied: openai>=1.99.5 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (1.109.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (0.7.0)
# Requirement already satisfied: tokenizers in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from litellm>=1.0.0->mcp2py) (0.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jinja2<4.0.0,>=3.1.2->litellm>=1.0.0->mcp2py) (2.1.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.0.0->mcp2py) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.0.0->mcp2py) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.0.0->mcp2py) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.0.0->mcp2py) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from aiohttp>=3.10->litellm>=1.0.0->mcp2py) (1.15.2)
# Requirement already satisfied: propcache>=0.2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from yarl<2.0,>=1.12.0->aiohttp>=3.10->litellm>=1.0.0->mcp2py) (0.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from importlib-metadata>=6.8.0->litellm>=1.0.0->mcp2py) (3.20.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from openai>=1.99.5->litellm>=1.0.0->mcp2py) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from openai>=1.99.5->litellm>=1.0.0->mcp2py) (0.9.1)
# Requirement already satisfied: tqdm>4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from openai>=1.99.5->litellm>=1.0.0->mcp2py) (4.67.1)
# Requirement already satisfied: email-validator>=2.0.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from pydantic[email]>=2.11.7->fastmcp) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp) (2.6.1)
# Requirement already satisfied: cffi>=1.12 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from cryptography->authlib>=1.5.2->fastmcp) (1.17.1)
# Requirement already satisfied: pycparser in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from cffi>=1.12->cryptography->authlib>=1.5.2->fastmcp) (2.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from rich>=13.9.4->fastmcp) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from rich>=13.9.4->fastmcp) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp) (0.1.2)
# Requirement already satisfied: regex>=2022.1.18 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from tiktoken>=0.7.0->litellm>=1.0.0->mcp2py) (2024.11.6)
# Requirement already satisfied: more-itertools in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.3.0,>=0.2.8->fastmcp) (10.8.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from tokenizers->litellm>=1.0.0->mcp2py) (0.36.0)
# Requirement already satisfied: filelock in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.0.0->mcp2py) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.0.0->mcp2py) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.0.0->mcp2py) (24.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/brianbagdasarian/projects/litellm/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm>=1.0.0->mcp2py) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from mcp2py import load

api = load('http://localhost:4000/mcp', headers={"Authorization": "Bearer sk-1234"})

scrape_tool = api.tools[0]

print(scrape_tool.__name__)
# Out:
# firecrawl_scrape

# %%
import dspy
from pydantic import BaseModel, Field
from typing import Any, Literal, Optional, Type

class Role(BaseModel):
    name: str = Field(description="The name of the role")
    role: str = Field(description="The role of the role")
    allow_instructions: bool = Field(description="Whether the role allows instructions")
    instructions: str | None = Field(description="The instructions for the role")

class Expectation(BaseModel):
    """
    An input that a runnable can expect.
    """
    type: Literal["string", "number", "boolean", "array", "object"] = Field(description="The type of the expectation")
    name: str = Field(description="The name of the expectation")
    default: Optional[Any] = Field(description="The default value of the expectation")
    description: str = Field(description="A description of the expectation")

class Returnable(BaseModel):
    type: Literal["string", "number", "boolean", "array", "object"] = Field(description="The type of the returnable")
    name: str = Field(description="The name of the returnable")
    description: str = Field(description="A description of the returnable")


def expectation_to_field_string(expectation: Expectation, custom_class: Optional[Type] = None) -> str:
    """
    Convert an Expectation to a DSPy field definition string.
    """
    type_map = {
        "string": "str",
        "number": "float",
        "boolean": "bool",
        "array": "list",
        "object": custom_class.__name__ if custom_class else "dict"
    }
    python_type = type_map[expectation.type]
    field_def = f'{expectation.name}: {python_type} = dspy.InputField(desc="{expectation.description}")'
    return field_def

def returnable_to_field_string(returnable: Returnable, custom_class: Optional[Type] = None) -> str:
    """
    Convert a Returnable to a DSPy field definition string.
    """
    type_map = {
        "string": "str",
        "number": "float",
        "boolean": "bool",
        "array": "list",
        "object": custom_class.__name__ if custom_class else "dict"
    }
    python_type = type_map[returnable.type]
    # Use OutputField for return values
    field_def = f'{returnable.name}: {python_type} = dspy.OutputField(desc="{returnable.description}")'
    return field_def


class Runnable(BaseModel):
    expects: dict[str, Expectation] = Field(description="The expected inputs of the runnable")
    name: str = Field(description="The name of the runnable")
    returns: dict[str, Returnable] = Field(description="The expected outputs of the runnable")
    defined_role: bool = Field(description="Whether the runnable has a defined role")
    role: Role = Field(description="If defined_role is true, the role object")
    fly_role: str = Field(description="If defined_role is false, the string role of the runnable")

    def generate_role(self) -> str:
        """Generate the role string for this runnable."""
        has_defined_role = self.defined_role 
        runnable_role = self.role.role if has_defined_role else self.fly_role
        return runnable_role

    def generate_expectations(self) -> list[str]:
        """Generate field strings for all expectations."""
        return [expectation_to_field_string(exp) for exp in self.expects.values()]

    def generate_returns(self) -> list[str]:
        """Generate field strings for all returns."""
        return [returnable_to_field_string(ret) for ret in self.returns.values()]

    def generate_module(self) -> Type[dspy.Signature]:
        """
        Generate a DSPy Signature class based on expectations and returns.
        
        Returns:
            A dspy.Signature subclass
        """
        # Get the role for the signature docstring
        role = self.generate_role()
        
        # Build the signature class dynamically
        signature_name = f"{self.name}Signature"
        class_lines = [
            f"class {signature_name}(dspy.Signature):",
            f'    """{role}"""',
        ]
        
        # Add input fields
        for exp in self.expects.values():
            field_str = expectation_to_field_string(exp)
            class_lines.append(f"    {field_str}")
        
        # Add output fields
        for ret in self.returns.values():
            field_str = returnable_to_field_string(ret)
            class_lines.append(f"    {field_str}")
        
        # Create the signature class
        signature_code = "\n".join(class_lines)
        namespace = {"dspy": dspy}
        exec(signature_code, namespace)
        signature_class = namespace[signature_name]
        
        return signature_class


# Example usage:
if __name__ == "__main__":
    # Create a sample runnable
    runnable = Runnable(
        name="SearchAgent",
        expects={
            "query": Expectation(
                type="string",
                name="query",
                default=None,
                description="The search query to execute"
            ),
            "max_results": Expectation(
                type="number",
                name="max_results",
                default=10,
                description="Maximum number of results"
            )
        },
        returns={
            "results": Returnable(
                type="string",
                name="results",
                description="The search results"
            )
        },
        defined_role=False,
        role=Role(name="", role="", allow_instructions=False, instructions=None),
        fly_role="You are a helpful search agent that processes queries and returns relevant results."
    )
    
    # Generate the signature
    signature = runnable.generate_module()
    print(f"Generated signature: {signature}")
    print(f"Signature name: {signature.__name__}")
    
    # You can now use it with a predictor
    predictor = dspy.Predict(signature)
    # result = predictor(query="example", max_results=5)
# Out:
# Writing runnable.py

# %%
from .runnable import Runnable
